# %% [markdown]
# <a href="https://colab.research.google.com/github/26404-droid/10704/blob/main/20260917.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[]
b=[10,20,30]
c=[1,2,'hello','hi']
d=[10,2.5,['hello','hi']]
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# [] <class 'list'>
# [10, 20, 30] <class 'list'>
# [1, 2, 'hello', 'hi'] <class 'list'>
# [10, 2.5, ['hello', 'hi']] <class 'list'>

# %%
a=[10,20,30,['a','b','c']]
b=[40,50,60,['a','b','c'],1.5,-5]
print(a[0])
print(a[-1])
print(a[3][0])
print(b[3][:2])
# Out:
# 10
# ['a', 'b', 'c']
# a
# ['a', 'b']

# %%
a=[4,2,3]
b=[4,5]
c=[1,2,[3,4]]
print(a+b)
print(a*3)
print(a<b)
print(len(a))
print(len(c))
print(len(c[2]))
# Out:
# [4, 2, 3, 4, 5]
# [4, 2, 3, 4, 2, 3, 4, 2, 3]
# True
# 3
# 3
# 2

# %%
a=[1,2,3,10,20]
print('원본:',a)
a[2]=4
print('결과1:',a)
a[3:]=[5,6]
print('결과2:',a)
a[2:]=[3,4]
print('결과3:',a)
del a[1]
print('결과4:',a)
del a[1:]
print('결과5:',a)
del a
# Out:
# 원본: [1, 2, 3, 10, 20]
# 결과1: [1, 2, 4, 10, 20]
# 결과2: [1, 2, 4, 5, 6]
# 결과3: [1, 2, 3, 4]
# 결과4: [1, 3, 4]
# 결과5: [1]
