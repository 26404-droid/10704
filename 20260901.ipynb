# %% [markdown]
# <a href="https://colab.research.google.com/github/26404-droid/10704/blob/main/20260901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요?")
print("반갑습니다.")
print("저는 김태현입니다.")
# Out:
# 안녕하세요?
# 반갑습니다.
# 저는 김태현입니다.
