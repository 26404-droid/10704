# %% [markdown]
# <a href="https://colab.research.google.com/github/26404-droid/10704/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a='hello'
b='world'
print(a + b)
print(a * 3)
print(a < b)
print('h' in a)
print('wor' not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a='Hello Python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
a='Hello Python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# Python
# Hello
# Py
# HloPt

# %%
a=input('주민등록번호 입력')
b=a[0:2]
c=a[2:4]
d=a[4:6]
print(f'{b}년 {c}월 {d}일')
# Out:
# 주민등록번호 입력101221
# 10년 12월 21일

# %%
a=input()
b1=a[::-1]
b2=b1.replace('e','3').replace('d','1').replace('q','2')
print('암호문:'+b2)
# Out:
# wqetwe
# 암호문:3wt32w
