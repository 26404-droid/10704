# %% [markdown]
# <a href="https://colab.research.google.com/github/26404-droid/10704/blob/main/20260908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('=====회전 초밥 영수증=====')
print('접시 단가 개수 합계')
빨간접시 = int(input('개수를 입력하세요'))
노란접시 = int(input('개수를 입력하세요'))
파란접시 = int(input('개수를 입력하세요'))
초록접시 = int(input('개수를 입력하세요'))
빨단 = 1000
파단 = 3000
노단 = 2000
초단 = 4000

print(f'빨간색 1,000 {빨간접시} {빨간접시*빨단}')
print(f'노란색 2,000 {노란접시} {노란접시*노단}')
print(f'파란색 3,000 {파란접시} {파란접시*파단}')
print(f'초록색 4,000 {초록접시} {초록접시*초단}')

빨간접시*빨단+파란접시*파단+초록접시*초단+노란접시*노단
# Out:
# =====회전 초밥 영수증=====
# 접시 단가 개수 합계
# 개수를 입력하세요1
# 개수를 입력하세요2
# 개수를 입력하세요3
# 개수를 입력하세요2
# 빨간색 1,000 1 1000
# 노란색 2,000 2 4000
# 파란색 3,000 3 9000
# 초록색 4,000 2 8000
# 22000
