# %% [markdown]
# <a href="https://colab.research.google.com/github/26404-droid/10704/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3+7
# 10 20 30 정보 프로그래밍

# %%
print('한양과학기술고등학교','1학년','김태현')
print('체질량 지수:',69/(175*175)*10000)
# Out:
# 한양과학기술고등학교 1학년 김태현
# 체질량 지수: 22.53061224489796

# %%
a=20
b=50
print(f'현재 온도는 {a}도, 습도는 {b}% 입니다.')
# Out:
# 현재 온도는 20도, 습도는 50% 입니다.

# %%
c=90
d=3.141592
print(f'직각은 {c}도, 원주율은 {d:0.2f}입니다.')
# Out:
# 직각은 90도, 원주율은 3.14입니다.

# %%
print('동해 물과 \'백두산\'이')
print('동해 물과 \"백두산"이')
print('마르고 닳도록')
print('하느님이 보우하사')
print('우리나라 만세')
print('무궁화 삼천리 화려 강산')
print('대한 사람 "대한"으로 길이 보전하세.')
print('2026-05-20')
# Out:
# 동해 물과 '백두산'이
# 동해 물과 "백두산"이
# 마르고 닳도록
# 하느님이 보우하사
# 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 "대한"으로 길이 보전하세.
# 2026-05-20

# %%
print('품목\t\t가격\t\t개수\n사과\t\t2,000\t\t8\n바나나\t\t3,000\t\t5')
# Out:
# 품목		가격		개수
# 사과		2,000		8
# 바나나		3,000		5

# %%
a=input('이름:')
b=input('나이:')
print(a, '님 안녕하세요?')
print(20-int(b), '년 후면 20살이네요!')
# Out:
# 이름:김태현
# 나이:17
# 김태현 님 안녕하세요?
# 3 년 후면 20살이네요!

# %%
print('###############################')
print('[한양과학기술고등학교 학생증]')
input('학번:')
input('성명:')
input('소속:')
print('위 학생은 본 학교의 학생임을 증명함.')
print('###############################')
# Out:
# ###############################
# [한양과학기술고등학교 학생증]
# 학번:10704
# 성명:김태현
# 소속:스마트전자과
# 위 학생은 본 학교의 학생임을 증명함.
# ###############################
